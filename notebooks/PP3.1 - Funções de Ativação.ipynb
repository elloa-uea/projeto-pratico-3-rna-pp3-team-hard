# %% [markdown]
# <a href="https://colab.research.google.com/github/HiagoOliver/RNA_ATIVIDADES/blob/main/funcoes_de_ativacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conhecendo as Funções de Ativação
#
# **Disciplina**: Redes Neurais Artificiais 2020.1
# **Professora**: Elloá B. Guedes (ebgcosta@uea.edu.br)
# **Github**: http://github.com/elloa
# **Dupla**:
# <ul>
#     <li>Dayvson dos Santos Silva</li>
#     <li>Hiago Oliveira de Jesus</li>
# </ul>
#
# ## Apresentação
#
# No contexto das redes neurais artificiais, as funções de ativação representam as transformações aplicadas às entradas do neurônio sujeitas aos respectivos graus de contribuição (pesos) para decidir se este neurônio deve ou não disparar. Ao considerar as redes neurais feedforward multilayer perceptron, tais funções de ativação devem ser contínuas e deriváveis, sendo responsáveis por realizarem transformações não-lineares sucessivas da informação fornecida na camada de entrada até a camada de saída, fazendo com que o problema vá tornando-se linearmente separável à medida que adentra-se na rede.
#
# Neste notebook, o seu objetivo é conhecer melhor as funções de ativação disponíveis na literatura e suas respectivas derivadas. Você irá construir gráficos que ilustrem tais funções.
#
# ## Requisitos
#
# - Utilizar numpy
# - Plotar com matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Intervalo de Entrada
#
# - Todas as funções devem ser ilustradas no intervalo [-4,+4] com amostras intervaladas em 0.1 no eixo x
# - Consulte a documentação de numpy.arange sobre como fazê-lo
# - https://numpy.org/doc/stable/reference/generated/numpy.arange.html#numpy.arange
# - Quantas amostras há em tal espaço de entrada?
# - Qual o tipo deste dado?
# - Qual a forma do espaço de entrada?

# %%
entrada = np.arange(-4,4,0.1)

# %% [markdown]
# ## Quantidade de amostras no espaço de entrada

# %%
entrada.size
# Out:
# 80

# %% [markdown]
# ## Descrição dos tipos de dados
#
# Os dados deste conjunto (numpy.ndarray) são do tipo float64, ou seja floats com 8 tamnho de 8 bytes

# %%
type(entrada), type(entrada[0])
# Out:
# (numpy.ndarray, numpy.float64)

# %% [markdown]
# ## Shape da entrada
# Essa entrada contém o shape (80, ), isso significa de possui 80 elementos

# %%
entrada.shape
# Out:
# (80,)

# %% [markdown]
# ## Função de ativação sigmoide
#
# $$f(x) = \frac{1}{1 + e^{-\beta \cdot x}}$$
#
# - Implemente uma função em Python que retorne o valor da função sigmóide para uma dada entrada
# - Nesta função, considere beta como parâmetro nomeado com valor igual a 1.0
# - Plote o gráfico da função no intervalo de entrada previamente especificado
# - Implemente uma função que retorne o valor da derivada da função sigmoide
# - Em um mesmo gráfico, ilustre 3 valores distintos para $\beta$:
#   - $\beta = 0.7$ na cor laranja
#   - $\beta = 0.5$ na cor verde
#   - $\beta = 0.3$ na cor vermelha
#   - Use legendas no gráfico

# %% [markdown]
# ### Implementação da função de ativação sigmoid

# %%
sigmoide = lambda x, beta: (1.0 / (1.0 + np.exp(-x*beta)))

# %% [markdown]
# ### Plotando a função sigmoid com os valores de entrada definidos no início

# %%
beta = np.array([0.7, 0.5, 0.3])
plt.plot(entrada, sigmoide(entrada, 1.0))
plt.title('Função Sigmóide')
plt.show()

# %%
derivada_sigmoide = lambda x, beta: (1.0 / (1.0 + np.exp(-beta * x))) * (1 - (1.0 / (1.0 + np.exp(-beta * x))))

# %% [markdown]
# ### Implementando a derivada da função sigmoide

# %%
plt.plot(entrada, derivada_sigmoide(entrada, 1.0))
title = 'Derivada Função Sigmóide'    
plt.title(title)
plt.show()

# %% [markdown]
# ### Plotando o gráfico da função sigmoide

# %%
for beta, marker in [(0.7, '--'), (0.5, '.'), (0.3, '-')]:
    plt.plot(entrada, sigmoide(entrada, beta), marker, label="beta - %s\n" % beta)

plt.legend()
plt.show()

# %% [markdown]
# ### Plotando a função de sigmoid para valores de beta diferentes
#
# - Os valores de beta servem para suavisar os gráficos da função

# %% [markdown]
# ## Função de Ativação ReLU (Unidade Linear Retificada)
#
# $$f(x) = max(0,x)$$
#
# - Implemente uma função em Python que retorne o valor da função ReLU para uma dada entrada
# - Plote o gráfico da função no intervalo de entrada previamente especificado
# - Implemente uma função que retorne o valor da derivada da função ReLU

# %% [markdown]
# ### Plotando os gráficos da derivada da função sigmoid para valores de beta diferentes

# %%
for beta, marker in [(0.7, '--'), (0.5, '.'), (0.3, '-')]:
    plt.plot(entrada, derivada_sigmoide(entrada, beta), marker, label="beta - %s\n" % beta)

plt.legend()
plt.show()

# %%
relu = lambda x: np.maximum(x, 0)

# %% [markdown]
# ### Implementado a função relu com numpy

# %%
plt.plot(entrada, relu(entrada))
plt.title('Função ReLU')
plt.show()

# %% [markdown]
# ### Plotando a função ReLU com as entradas inicias

# %% [markdown]
# <h3 align='center'>Derivada da função de ativação ReLU. </h3>
#
# $$f'(x) = \left \{ \begin{matrix} 0, & \mbox{se }x\mbox{ < 0} \\ 1, & \mbox{se }x \geq \mbox{0}\end{matrix} \right.$$

# %%
derivada_relu = lambda x: 1.0 if x >= 0.0 else 0.0

# %% [markdown]
# ### Implementando a derivada da função ReLU

# %%
plt.plot(entrada, [derivada_relu(x) for x in entrada])
plt.title('Derivada Função ReLU')
plt.show()

# %% [markdown]
# ### Plotando o gráfico da derivada da função ReLU para os valores de entrada

# %% [markdown]
# ## Função de ativação linear (purelin)
#
# $$f(x) = x$$
#
# - Implemente uma função em Python que retorne o valor da função linear para uma dada entrada
# - Plote o gráfico da função no intervalo de entrada previamente especificado
# - Implemente uma função que retorne o valor da derivada da função em questão

# %% [markdown]
# ## Função purelin

# %%
purelin = lambda x: x

# %% [markdown]
# ### Implementado a função Purelin

# %%
plt.plot(entrada, purelin(entrada))
plt.title('Função Purelin')
plt.show()

# %% [markdown]
# ### Plotando o gráfico da função purilin

# %% [markdown]
# <h3 align='center'>Derivada da função de ativação Purelin. </h3>
#
# $$f'(x) = 1.x^{1-1}$$

# %%
derivada_purelin = lambda x: (1 * (x ** (1-1)))

# %% [markdown]
# ### Implementando a derivada da função purelin

# %%
plt.plot(entrada, derivada_purelin(entrada))
plt.title('Derivada Função Purelin')
plt.show()

# %% [markdown]
# ### Plotando o gráfico da derivada da função purilin

# %% [markdown]
# ## Função de ativação Tangente Hiperbólica
#
# $$f(x) = tanh(x)$$
#
# - Implemente uma função em Python que retorne o valor da função tangente hiperbólica para uma dada entrada
# - Plote o gráfico da função no intervalo de entrada previamente especificado
# - Implemente uma função que retorne o valor da derivada da função em questão
# - Utilize bibliotecas para auxiliar nesta tarefa
# - Considere o intervalo (-1,1)

# %%
entrada_tanh = np.arange(-1, 1, 0.0001)
tanh = lambda x: np.tanh(x)

# %% [markdown]
# ### Implementadando a derivada da função Tangente Hiperbólica

# %%
plt.plot(entrada_tanh, tanh(entrada_tanh))
plt.title('Função Tangente Hiberbólica')
plt.show()

# %% [markdown]
# ### Plotando o gráfico da função Tangente Hiperbólica no intervalo \[-1, 1\]

# %% [markdown]
# <h3 align='center'>Derivada da função de ativação Tangente Hiperbólica. </h3>
#
# $$f'(x) = 1−tanh^2(x)$$

# %%
derivada_tanh = lambda x: 1.0 - (np.tanh(x)**2)

# %% [markdown]
# ### Implementando a derivada da função Tangente Hiperbólica

# %%
plt.plot(entrada_tanh, derivada_tanh(entrada_tanh))
plt.title('Derivada Função Tangente Hiberbólica')
plt.show()

# %% [markdown]
# ### Plotando o gráfico da funçao Tangente Hiperbólica no intervalo \[-1, 1\]

# %% [markdown]
# ### Função de Ativação Gaussiana
#
# $$f(x) = \exp \left( \frac{-(x - \mu)^2}{2\sigma^2} \right)$$
#
# - $\mu$ é o ponto médio (centro) da curva
# - $\sigma$ denota o raio de abertura
# - Implemente uma função em Python que retorne o valor da função gaussiana para uma dada entrada
# - Plote o gráfico da função no intervalo de entrada previamente especificado
# - Implemente uma função que retorne o valor da derivada da função em questão
#
#
# Considere também os seguintes valores ao plotar a função
#
# - Parâmetros nomeados $\mu = 0$ e $\sigma = 1$
# - $\mu = 0, \sigma = 0.3$
# - $\mu = 0, \sigma = 0.5$
# - $\mu = 0, \sigma = 0.7$
# - $\mu = 0, \sigma = 0.9$
# - $\mu = 0, \sigma = 1.1$

# %%
gaussiana = lambda x, u=0, o=1: np.exp((-(x - u )**2) / (2 * (o**2)))

# %% [markdown]
# ### Implementando a função Gaussiana

# %%
for raio, marker in [(0.3, '+'), (0.5, '-'), (0.7, '--'), (0.9, '_'), (1.1, '.')]:
    plt.plot(entrada, gaussiana(entrada, 0, raio), marker, label="raio - %s\n" % raio)
plt.title('Função Gaussiana')
plt.legend()
plt.show()

# %% [markdown]
# ### Plotando o gráfico da função Gaussiana

# %% [markdown]
# <h3 align='center'>Derivada da função de ativação Gaussiana de ordem = 0.</h3>
#
# $$f'(x) = f(x)$$

# %%
derivada_gaussiana = lambda x: gaussiana(x)
plt.plot(entrada, derivada_gaussiana(entrada), label='Raio - 1\nPonto Médio - 0') 
plt.title('Derivada Função Gaussiana de ordem 0')
plt.legend()
plt.show()

# %% [markdown]
# <h3 align='center'>Derivada da função de ativação Gaussiana de ordem = 1.</h3>
#
# $$f'(x) =-\dfrac{\left(x-\mu\right)\mathrm{e}^{-\frac{\left(x-\mu\right)^2}{2\sigma^2}}}{\sigma^2}$$

# %%
def derivada_gaussiana_ordem_1(x, m=0, s=1):
    return (-((x-m)*math.e**(-(x-m)**2/(2*s**2)))/s**2)
    
plt.plot(entrada, derivada_gaussiana_ordem_1(entrada), label='Raio - 1\nPonto Médio - 0') 
plt.title('Derivada Função Gaussiana de ordem 1')
plt.legend()
plt.show()

# %% [markdown]
# <h3 align='center'>Derivada da função de ativação Gaussiana de ordem = 2.</h3>
#
# $$f' '(x) =\dfrac{\left(x-\mu\right)^2\mathrm{e}^{-\frac{\left(x-\mu\right)^2}{2\sigma^2}}}{\sigma^4}-\dfrac{\mathrm{e}^{-\frac{\left(x-\mu\right)^2}{2\sigma^2}}}{\sigma^2}$$

# %%
def derivada_gaussiana_ordem_2(x, m=0, s=1):
    return ((x-m)**2*math.e**(-(x-m)**2/(2*s**2)))/s**4-e**(-(x-m)**2/(2*s**2))/s**2
    
plt.plot(entrada, derivada_gaussiana_ordem_2(entrada), label='Raio - 1\nPonto Médio - 0') 
plt.title('Derivada Função Gaussiana de ordem 2')
plt.legend()
plt.show()

# %% [markdown]
# ## Função de Ativação Leaky ReLU
#
# $$f(x) = \left\{\begin{array}{cc} 0.01\cdot x & x < 0\\ x & x \geq 0 \end{array} \right.$$
#
# - Implemente uma função em Python que retorne o valor da função Leaky ReLU para uma dada entrada
# - Plote o gráfico da função no intervalo de entrada previamente especificado
# - Implemente uma função que retorne o valor da derivada da função Leaky ReLU

# %%
leaky_relu = lambda x, a=0.0: (a * x) if x < 0.0 else x

# %%
plt.plot(entrada, [leaky_relu(x) for x in entrada])
plt.title('Função LeaKy ReLU')
plt.show()

# %% [markdown]
# <h3 align='center'>Derivada da função de ativação Leaky ReLU. </h3>
#
# $$f'(x) = \left\{\begin{array}{cc} 0.01 & x < 0\\ 1 & x \geq 0 \end{array} \right.$$

# %%
derivada_leaky = lambda x, a=0.01: 1 if x >= 0 else a

# %%
plt.plot(entrada, [derivada_leaky(x) for x in entrada])
plt.title('Função LeaKy ReLU')
plt.show()

# %% [markdown]
# **Referências**

# %% [markdown]
# <a href="https://www.geeksforgeeks.org/numpy-tanh-python/"> np.tanh()</a><br>
# <a href="http://deeplearningbook.com.br/funcao-de-ativacao/">Funções de ativação</a><br>
# <a href="https://matheusfacure.github.io/2017/07/12/activ-func/">Derivadas das funções de ativação</a><br>
# <a href="https://pt.qwe.wiki/wiki/Gaussian_function"> Função Gaussiana </a> <br>
# <a href="https://pt.qwe.wiki/wiki/Hermite_polynomials">Derivada da função Gaussiana </a> <br>
# <a href="href="http://www.sci.utah.edu/~gerig/CS7960-S2010/handouts/04%20Gaussian%20derivatives.pdf">Derivada da função Gaussiana 2 </a> <br>
